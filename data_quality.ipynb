# %% [markdown]
# # Data Quality Notebook
# This notebook loads the dataset and performs basic data quality checks.

# %%
import pandas as pd
df = pd.read_csv('/mnt/data/Features data set.csv')
df.head()

# %% [markdown]
# ## Missing Values Check

# %%
df.isnull().mean().sort_values(ascending=False)

# %% [markdown]
# ## Date Parsing Attempt

# %%
df['Date_parsed'] = pd.to_datetime(df['Date'], errors='coerce', infer_datetime_format=True)
df['Date_parsed'].isnull().sum()
